# %%
pip install numpy pandas pillow matplotlib opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\ElChino\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from fotoapp import *
# Out:
# Menu de opciones:
# 1. Redimensionar Imagen
# 2. Ajustar Contraste
# 3. Aplicar Filtro
# 4. Dibujar Boceto de Persona
# 5. Salir
# Seleccione una opción (1-5): 1
# Ingrese la ruta de la imagen: images/indio.jpg
# Ingrese la palabra clave (Youtube, Instagram, Twitter, Facebook): twitter

# %%
# Prueba redimensionar imagenes
imagen = 'images/indio.jpg'
redimensionar_imagen(imagen,'Instagram')

# %%
# Prueba de la función contraste con foto oscura
imagen = 'images/FOTO-OSCURA.jpg'
contraste(imagen)

# %%
# Prueba de la función contraste con foto con exceso de luz
image_path = 'images/FOTO-LUZ.jpg'
contraste(image_path)

# %%
#Prueba de la funcion filtros
imagen = 'images/spiderman.jpeg'
filtros(imagen,'CONTOUR')

# %%
#Prueba de la funcion imagen_binarizada
imagen = 'images/persona.png'
imagen_binarizada(imagen)
